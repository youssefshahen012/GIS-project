# %%
import geopandas as gpd

# %%
gdf = gpd.read_file('gadm41_EGY_2.shp')

# %%
gdf
# Out:
#            GID_2 GID_0 COUNTRY     GID_1         NAME_1 NL_NAME_1  \
# 0      EGY.1.1_1   EGY   Egypt   EGY.1_1  Ad Daqahliyah  الدقهلية
# 1      EGY.1.2_1   EGY   Egypt   EGY.1_1  Ad Daqahliyah  الدقهلية
# 2      EGY.1.3_1   EGY   Egypt   EGY.1_1  Ad Daqahliyah  الدقهلية
# 3      EGY.1.4_1   EGY   Egypt   EGY.1_1  Ad Daqahliyah  الدقهلية
# 4      EGY.1.5_1   EGY   Egypt   EGY.1_1  Ad Daqahliyah  الدقهلية
# ..           ...   ...     ...       ...            ...       ...
# 338  EGY.27.14_1   EGY   Egypt  EGY.27_1          Suhaj        NA
# 339  EGY.27.15_1   EGY   Egypt  EGY.27_1          Suhaj        NA
# 340  EGY.27.16_1   EGY   Egypt  EGY.27_1          Suhaj        NA
# 341  EGY.27.17_1   EGY   Egypt  EGY.27_1          Suhaj        NA
# 342  EGY.27.18_1   EGY   Egypt  EGY.27_1          Suhaj        NA
#
#                    NAME_2 VARNAME_2 NL_NAME_2       TYPE_2    ENGTYPE_2 CC_2  \
# 0                     Aja       Aga        NA       Markaz  Subdivision   NA
# 1            Al-Jamaliyah        NA        NA         Kism  Subdivision   NA
# 2             Al-Mansurah        NA        NA       Markaz  Subdivision   NA
# 3           Al-Mansurah 1        NA        NA         Kism  Subdivision   NA
# 4           Al-Mansurah 2        NA        NA       Markaz  Subdivision   NA
# ..                    ...       ...       ...          ...          ...  ...
# 338              Sawhaj 2        NA        NA         Kism  Subdivision   NA
# 339                 Tahta        NA        NA       Markaz  Subdivision   NA
# 340            Tahta City        NA        NA         Kism  Subdivision   NA
# 341                  Tima        NA        NA       Markaz  Subdivision   NA
# 342  Unorganized in Suhaj        NA        NA  unorganized  Subdivision   NA
#
#        HASC_2                                           geometry
# 0    EG.DQ.AG  POLYGON ((31.30377 30.99935, 31.31002 30.99356...
# 1    EG.QH.GA  POLYGON ((31.99799 31.22747, 31.98231 31.22915...
# 2    EG.DQ.MA  POLYGON ((31.39126 30.93035, 31.38016 30.96288...
# 3    EG.DQ.MF  POLYGON ((31.39234 31.01250, 31.37525 31.00095...
# 4    EG.DQ.MK  POLYGON ((31.39234 31.01250, 31.38253 31.03385...
# ..        ...                                                ...
# 338  EG.SJ.SS  POLYGON ((31.70411 26.56144, 31.70938 26.54274...
# 339  EG.SJ.TM  POLYGON ((31.50795 26.85638, 31.51352 26.84279...
# 340  EG.SJ.TK  POLYGON ((31.49783 26.74574, 31.48510 26.74924...
# 341  EG.SJ.TA  POLYGON ((31.44358 26.94474, 31.48056 26.91307...
# 342  EG.IK.UO  MULTIPOLYGON (((31.87967 26.19733, 31.76193 26...
#
# [343 rows x 14 columns]

# %%
gdf.plot()
# Out:
# <Axes: >

# %%
ax= gdf.plot(column='NAME_1', figsize=(10,6), edgecolor='black', legend=True)

# %%
gdf.plot(column = 'NAME_1', cmap = 'plasma', figsize = (10,10))
# Out:
# <Axes: >
